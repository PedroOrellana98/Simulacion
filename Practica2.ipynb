# %% [markdown]
# <img src="https://pure.ups.edu.ec/skin/footerIcon/"/>
#
# **Nombres:**  Pedro Jose Orellana
#
# **Tema:**  Ejercicios de la Unidad 1

# %% [markdown]
# ## Ejercicio 1
#
# **Utilizar Matplot y Plotly para realizar las graficas.**
#
# **1 Con los datos de Fifa, organizar a los jugadores de acuerdo al peso en las siguientes escalas y generar un cuadro tipo PIE**
#
# * Debajo 125 Lbs.
# * 125-150
# * 150-175
# * 175 o superior

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

directorio = "/content/drive/MyDrive/Simulacion/Fifa/fifa_datos.csv"
df = pd.read_csv(directorio)
df['Weight'] = df['Weight'].str.replace('lbs','')
peso = df.loc[:,"Weight"]
np=peso.values
#print(np)

list1 = []
list2 = []
list3 = []
list4 = []
vector0 = []
vector1 = []
vector2 = []
vector3 = []

for i in range(125, 151):
    list1.append(str(i).zfill(1))

for i in peso:
  for j in list1:
    if i == j:
      vector0.append(i)

print(len(vector0))

for i in range(0, 125):
    list2.append(str(i).zfill(1))

for i in peso:
  for j in list2:
    if i == j:
      vector1.append(i)

print(len(vector1))

for i in range(150, 176):
    list3.append(str(i).zfill(1))

for i in peso:
  for j in list3:
    if i == j:
      vector2.append(i)

print(len(vector2))

for i in range(176, 300):
    list4.append(str(i).zfill(1))

for i in peso:
  for j in list4:
    if i == j:
      vector3.append(i)

print(len(vector3))

plt.figure()

etiquetas = ['Peso Medio 1', 'Peso Bajo', 'Peso Medio2', 'Peso Alto']
colores = ['#abcdef', '#aabbcc', '#abcabc', '#ccbbaa']
plt.pie([len(vector0), len(vector1), len(vector2), len(vector3)], labels=etiquetas, colors=colores, autopct='%.2f %%')
plt.title('Escalas de dataset Fifa')
plt.show()
# Out:
# 2950
# 41
# 10876
# 4952

# %% [markdown]
# **2 Generar un grafico de barras (histograma) de acuerdo a su habilidad (Overall)  en base a los siguientes segmentos contando el número de jugadores**
#
# * 40
# * 50
# * 60
# * 70
# * 80
# * 90

# %%
import matplotlib.pyplot as plot
general = df.loc[:,"Overall"]
np=general.values
cuarenta = []
cincuenta = []
sesenta = []
setenta = []
ochenta = []
noventa = []

for i in general:
    if i == 40:
      cuarenta.append(i)
    if i == 50:
      cincuenta.append(i) 
    if i == 60:
      sesenta.append(i) 
    if i == 70:
      setenta.append(i) 
    if i == 80:
      ochenta.append(i) 
    if i == 90:
      noventa.append(i)   

print("Vector de 40 = " + str(len(cuarenta)) 
+ "\nVector de 50 = " + str(len(cincuenta))
+ "\nVector de 60 = " + str(len(sesenta))
+ "\nVector de 70 = " + str(len(setenta))
+ "\nVector de 80 = " + str(len(ochenta))
+ "\nVector de 90 = " + str(len(noventa)))

vec = [cuarenta,cincuenta,sesenta,setenta,ochenta,noventa]
valores = [40, 50, 60, 70, 80, 90]
colore = ['#abcdef', '#aabbcc', '#abcabc', '#ccbbaa', '#bbbbaa', '#ccccbb']

plot.hist(x=vec, bins=valores, color=colore)
plot.title('Histograma Overall')
plot.xlabel('General')
plot.ylabel('Frecuencia')
plot.xticks(valores)

plot.show() #dibujamos el histograma
# Out:
# Vector de 40 = 0
# Vector de 50 = 103
# Vector de 60 = 649
# Vector de 70 = 889
# Vector de 80 = 143
# Vector de 90 = 5
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
import matplotlib.pyplot as plot
general = df.loc[:,"Overall"]
np=general.values
#print(np)

def cuarentaJugadores():
  vector = []
  for i in range(0, 40):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 40 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

def cincuentaJugadores():
  vector = []
  for i in range(0, 50):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 50 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

def sesentaJugadores():
  vector = []
  for i in range(0, 60):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 60 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

def setentaJugadores():
  vector = []
  for i in range(0, 70):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 70 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

def ochentaJugadores():
  vector = []
  for i in range(0, 80):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 80 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

def noventaJugadores():
  vector = []
  for i in range(0, 90):
      vector.append(general[i])
  print("Dimension: " + str(len(vector)))

  intervalos = range(min(vector), max(vector) + 2)

  plot.hist(x=vector, bins=intervalos, color='#F2AB6D', rwidth=0.85)
  plot.title('Histograma 90 jugadores')
  plot.xlabel('General')
  plot.ylabel('Frecuencia')
  plot.xticks(intervalos)

  plot.show() #dibujamos el histograma

cuarentaJugadores()
cincuentaJugadores()
sesentaJugadores()
setentaJugadores()
ochentaJugadores()
noventaJugadores()
# Out:
# Dimension: 40
# Dimension: 50
# Dimension: 60
# Dimension: 70
# Dimension: 80
# Dimension: 90

# %% [markdown]
# **3 Investigar alguna herramienta o software que permita generar reportes con Python utilizando CodeLabs.**
#
# Archivo de imágenes, análisis y generación de informes con G Suite y GCP
#
# Este codelab imagina un posible flujo de trabajo empresarial: archivo de imágenes, análisis y generación de informes. Imagine a su organización que tiene una serie de imágenes que ocupan espacio en un recurso limitado. Deseas archivar esos datos, analizar esas imágenes y, lo que es más importante, generar un informe que resuma las ubicaciones archivadas y los resultados del análisis, recopilados y preparado para el consumo. Google Cloud proporciona las herramientas para que esto suceda, utilizando API de dos de sus líneas de productos, G Suite y Google Cloud Platform (GCP).
#
# Tomado de: https://codelabs.developers.google.com/codelabs/drive-gcs-vision-sheets?hl=es_419#0
